# %%
import cobra as cb

# %%
model = cb.io.read_sbml_model('C:/Users/iamab/iGEM-IITB/FBA/Metabolic_Reconstructions/MODEL1108160000_url.xml')
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_10fthf_c "10-Formyltetrahydrofolate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_10fthf_c "10-Formyltetrahydrofolate">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_12dgr120_c "1,2-Diacyl-sn-glycerol (didodecanoyl, n-C12:0)">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_12dgr120_c "1,2-Diacyl-sn-glycerol (didodecanoyl, n-C12:0)">
# Use of CHARGE in the notes element is discouraged, use fbc:charge instead: <Species M_12dgr140_c "1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)">
# ...

# %%
model1 = cb.io.read_sbml_model('C:/Users/iamab/iGEM-IITB/FBA/Metabolic_Reconstructions/MODEL4665428627_url.xml')
# Out:
# Model does not contain SBML fbc package information.
# '' is not a valid SBML 'SId'.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Adding exchange reaction EX_Hxt with default bounds for boundary metabolite: Hxt.
# Adding exchange reaction EX_GLCxt with default bounds for boundary metabolite: GLCxt.
# Adding exchange reaction EX_CO2xt with default bounds for boundary metabolite: CO2xt.
# Adding exchange reaction EX_O2xt with default bounds for boundary metabolite: O2xt.
# Adding exchange reaction EX_NO3xt with default bounds for boundary metabolite: NO3xt.
# Adding exchange reaction EX_NO2xt with default bounds for boundary metabolite: NO2xt.
# Adding exchange reaction EX_ETHxt with default bounds for boundary metabolite: ETHxt.
# Adding exchange reaction EX_Acxt with default bounds for boundary metabolite: Acxt.
# ...

# %%
model2 = cb.io.read_sbml_model('C:/Users/iamab/iGEM-IITB/FBA/Metabolic_Reconstructions/ecoli_core.xml')
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_13dpg_c "3-Phospho-D-glyceroyl-phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_2pg_c "D-Glycerate-2-phosphate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_3pg_c "3-Phospho-D-glycerate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6pgc_c "6-Phospho-D-gluconate">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_6pgl_c "6-phospho-D-glucono-1-5-lactone">
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_ac_c "Acetate">
# ...

# %%
print(f"The reactions, metabolites and genes in the ecoli k12 bigger model are: {len(model.reactions)}, {len(model.metabolites)}, {len(model.genes)}")
# Out:
# The reactions, metabolites and genes in the ecoli k12 bigger model are: 2583, 1805, 1367

# %%
soln1 = model.optimize()
print(soln1)
soln2 = model1.optimize()
print(soln2)
soln3 = model2.optimize()
print(soln3)
# Out:
# <Solution 0.982 at 0x2b3d467eaa0>
# <Solution 0.000 at 0x2b3d3e27940>
# <Solution infeasible at 0x2b3cddb98a0>
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)

# %%
print(soln1.fluxes)
print(f"the final objective function value is {soln1.objective_value}")
print(type(soln1.fluxes))
# Out:
# DM_4CRSOL    0.000219
# DM_5DRIB     0.000221
# DM_AACALD    0.000000
# DM_AMOB      0.000002
# DM_MTHTHF    0.000440
#                ...
# ZN2abcpp     0.000000
# ZN2t3pp      0.000000
# ZN2tpp       0.000335
# ZNabcpp      0.000000
# Zn2tex       0.000335
# Name: fluxes, Length: 2583, dtype: float64
# the final objective function value is 0.9823718127270189
# <class 'pandas.core.series.Series'>

# %%
model.reactions.get_by_id("EX_glc_LPAREN_e_RPAREN_").bounds=(-18.5, 1000)

# %% [markdown]
# In the context of cobrapy and flux balance analysis (FBA), **shadow prices** refer to the dual values associated with the constraints in a linear programming problem. Here's how they are described on the web page you're viewing:
#
# - **Shadow Prices** : These are part of the `Solution` object returned by the `Model.optimize()` function in cobrapy. They are represented as a pandas series indexed by the metabolite identifier¹[1].
# - **Purpose**: Shadow prices provide insight into how much the objective value (such as biomass production) would change if the availability of a particular metabolite were to be increased or decreased slightly.
# - **Interpretation**: A positive shadow price indicates that if the supply of the corresponding metabolite is increased by one unit, the objective value will increase by the shadow price value. Conversely, a negative shadow price suggests that increasing the supply of the metabolite would decrease the objective value.
#
# This concept is crucial in metabolic engineering and systems biology for understanding the sensitivity of metabolic networks to changes in metabolite levels and identifying potential bottlenecks in metabolic pathways.

# %%
model.reactions.get_by_id("EX_o2_LPAREN_e_RPAREN_").bounds=(-1000, 1000)

# %%
model.objective= "Ec_biomass_iJO1366_WT_53p95M"

# %%
soln=model.optimize()

# %%
print(soln)
# Out:
# <Solution 1.836 at 0x2b3d479d780>

# %%
print(soln.fluxes)
# Out:
# DM_4CRSOL    0.000409
# DM_5DRIB     0.000424
# DM_AACALD    0.000000
# DM_AMOB      0.000004
# DM_MTHTHF    0.002461
#                ...
# ZN2abcpp     0.000000
# ZN2t3pp      0.000000
# ZN2tpp       0.000595
# ZNabcpp      0.000000
# Zn2tex       0.000595
# Name: fluxes, Length: 2583, dtype: float64

# %%
model.reactions.get_by_id("EX_glc_LPAREN_e_RPAREN_").bounds=(0, 1000)

# %%
model.reactions.get_by_id("EX_succ_LPAREN_e_RPAREN_").bounds=(-20, 1000)

# %%
soln=model.optimize()

# %%
print(soln)
# Out:
# <Solution 1.002 at 0x296ea0672b0>

# %%
model.reactions.get_by_id("EX_o2_LPAREN_e_RPAREN_").bounds=(-1000, 1000)

# %%
soln=model.optimize()
print(soln)
# Out:
# <Solution 1.002 at 0x296ea067df0>

# %%
'''model.reactions.get_by_id("EX_glc_LPAREN_e_RPAREN_").bounds=(-1, -1)
model.reactions.get_by_id("ATPM").bounds=(0, 1000)
model.objective= "ATPM"
soln=model.optimize()
print(soln)'''
# Out:
# 'model.reactions.get_by_id("EX_glc_LPAREN_e_RPAREN_").bounds=(-1, -1)\nmodel.reactions.get_by_id("ATPM").bounds=(0, 1000)\nmodel.objective= "ATPM"\nsoln=model.optimize()\nprint(soln)'

# %%
'''model.reactions.get_by_id("EX_glc_LPAREN_e_RPAREN_").bounds=(-1, -1)
model.reactions.get_by_id("ATPM").bounds=(0, 0)
'''
# Out:
# 'model.reactions.get_by_id("EX_glc_LPAREN_e_RPAREN_").bounds=(-1, -1)\nmodel.reactions.get_by_id("ATPM").bounds=(0, 0)\n'

# %%
'''metabolite_A = cb.Metabolite('nadh_c')
metabolite_B = cb.Metabolite('nad_c')
metabolite_C = cb.Metabolite('h_c')
# Create a new reaction
reaction = cb.Reaction('NADH_drain')
reaction.name = 'NADH_drain'

# Add metabolites to the reaction
reaction.add_metabolites({
    metabolite_A: -1,  # This means metabolite_A is a reactant with a coefficient of -1
    metabolite_B: 1,   # This means metabolite_B is a product with a coefficient of 1
    metabolite_C: 1
})

# Add the reaction to the model
model.add_reactions([reaction])'''
# Out:
# "metabolite_A = cb.Metabolite('nadh_c')\nmetabolite_B = cb.Metabolite('nad_c')\nmetabolite_C = cb.Metabolite('h_c')\n# Create a new reaction\nreaction = cb.Reaction('NADH_drain')\nreaction.name = 'NADH_drain'\n\n# Add metabolites to the reaction\nreaction.add_metabolites({\n    metabolite_A: -1,  # This means metabolite_A is a reactant with a coefficient of -1\n    metabolite_B: 1,   # This means metabolite_B is a product with a coefficient of 1\n    metabolite_C: 1\n})\n\n# Add the reaction to the model\nmodel.add_reactions([reaction])"

# %%
'''model.objective= "NADH_drain"
soln=model.optimize()
print(soln)'''
# Out:
# 'model.objective= "NADH_drain"\nsoln=model.optimize()\nprint(soln)'

# %%
'''model.objective= "ME1"
model.reactions.get_by_id("Ec_biomass_iJO1366_WT_53p95M").bounds=(1.001, 1.001)
model.objective_direction = "max"'''
# Out:
# 'model.objective= "ME1"\nmodel.reactions.get_by_id("Ec_biomass_iJO1366_WT_53p95M").bounds=(1.001, 1.001)\nmodel.objective_direction = "max"'

# %%
soln=model.optimize()
print(soln)
# Out:
# <Solution 1.002 at 0x296ea0a4a30>

# %%
model.reactions.get_by_id("EX_o2_LPAREN_e_RPAREN_").bounds=(-17, -17)
import numpy as np
glucose_uptake_rates = np.zeros((2001,1))
growth_rates = np.zeros((2001, 1))
for i in range(2000):
    model.reactions.get_by_id("EX_glc_LPAREN_e_RPAREN_").bounds=(-i, -i)
    glucose_uptake_rates[i]=i
    soln=model.optimize()
    growth_rates[i+1]=soln.objective_value
glucose_uptake_rates[2000]=2000
# Out:
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(glucose_uptake_rates, growth_rates, marker='o')
plt.xlabel('Glucose Uptake Rate')
plt.ylabel('Growth Rate')
plt.title('Growth Rate vs Glucose Uptake Rate')
plt.grid(True)
plt.show()

# %%
import numpy as np
glucose_uptake_rates = np.zeros((101,1))
o2_rates=np.zeros((101,1))
growth_rates = np.zeros((101, 101))
for i in range(100):
    for j in range(100):
        model.reactions.get_by_id("EX_glc_LPAREN_e_RPAREN_").bounds=(-i, -i)
        model.reactions.get_by_id("EX_o2_LPAREN_e_RPAREN_").bounds=(-j, -j)
        glucose_uptake_rates[i]=i
        o2_rates[i]=i
        soln=model.optimize()
        growth_rates[i+1][j+1]=soln.objective_value
glucose_uptake_rates[100]=100
o2_rates[100]=100
# Out:
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# C:\Users\iamab\anaconda3\lib\site-packages\cobra\util\solver.py:554: UserWarning: Solver status is 'infeasible'.
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the function
ax.plot_surface( glucose_uptake_rates, o2_rates, growth_rates, cmap='viridis')
# Set labels
ax.set_xlabel('glucose')
ax.set_ylabel('o2')
ax.set_zlabel('growth')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(glucose_uptake_rates, growth_rates, marker='o')
plt.xlabel('Glucose Uptake Rate')
plt.ylabel('Growth Rate')
plt.title('Growth Rate vs Glucose Uptake Rate')
plt.grid(True)
plt.show()

# %%
growth_rates
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        , -0.05244145,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.04105851, ...,  0.08684326,
#          0.08684326,  0.08684326],
#        ...,
#        [ 0.        ,  2.65295473,  2.71015835, ...,  7.20763438,
#          7.25029257,  7.29295076],
#        [ 0.        ,  2.68066472,  2.73794345, ...,  7.23962803,
#          7.28228622,  7.32494441],
#        [ 0.        ,  2.70837472,  2.76572854, ...,  7.27162167,
#          7.31427986,  7.35693805]])
